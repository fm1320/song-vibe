# %%
# !pip list
# Out:
# Package                   Version         Editable project location
# ------------------------- --------------- ----------------------------------------
# altair                    5.2.0
# anyio                     4.3.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.7.0
# cachetools                5.3.3
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# click                     8.1.7
# comm                      0.2.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.2.0
# executing                 2.0.1
# faiss-cpu                 1.8.0
# fastjsonschema            2.19.1
# filelock                  3.13.1
# fqdn                      1.5.1
# fsspec                    2024.2.0
# gitdb                     4.0.11
# GitPython                 3.1.42
# h11                       0.14.0
# httpcore                  1.0.4
# httpx                     0.27.0
# huggingface-hub           0.21.3
# idna                      3.6
# importlib-metadata        7.0.1
# ipykernel                 6.29.3
# ipython                   8.22.1
# ipywidgets                8.1.2
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.3
# joblib                    1.3.2
# json5                     0.9.20
# jsonpointer               2.4
# jsonschema                4.21.1
# jsonschema-specifications 2023.12.1
# jupyter                   1.0.0
# jupyter_client            8.6.0
# jupyter-console           6.6.3
# jupyter_core              5.7.1
# jupyter-events            0.9.0
# jupyter-lsp               2.2.3
# jupyter_server            2.12.5
# jupyter_server_terminals  0.5.2
# jupyterlab                4.1.2
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.25.3
# jupyterlab_widgets        3.0.10
# markdown-it-py            3.0.0
# MarkupSafe                2.1.5
# matplotlib-inline         0.1.6
# mdurl                     0.1.2
# mistune                   3.0.2
# mpmath                    1.3.0
# nbclient                  0.9.0
# nbconvert                 7.16.1
# nbformat                  5.9.2
# nest-asyncio              1.6.0
# networkx                  3.2.1
# notebook                  7.1.1
# notebook_shim             0.2.4
# numpy                     1.26.4
# overrides                 7.7.0
# packaging                 23.2
# pandas                    2.2.1
# pandocfilters             1.5.1
# parso                     0.8.3
# pexpect                   4.9.0
# pillow                    10.2.0
# pip                       23.0
# platformdirs              4.2.0
# prometheus_client         0.20.0
# prompt-toolkit            3.0.43
# protobuf                  4.25.3
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pyarrow                   15.0.0
# pycparser                 2.21
# pydeck                    0.8.0
# Pygments                  2.17.2
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pytz                      2024.1
# PyYAML                    6.0.1
# pyzmq                     25.1.2
# qtconsole                 5.5.1
# QtPy                      2.4.1
# referencing               0.33.0
# regex                     2023.12.25
# requests                  2.31.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.7.1
# rpds-py                   0.18.0
# safetensors               0.4.2
# scikit-learn              1.4.1.post1
# scipy                     1.12.0
# Send2Trash                1.8.2
# sentence-transformers     2.5.1
# setuptools                67.2.0
# six                       1.16.0
# smmap                     5.0.1
# sniffio                   1.3.1
# song-vibe                 0.1.0           /Users/Antonio.Morais/Work/LLM/song-vibe
# soupsieve                 2.5
# stack-data                0.6.3
# streamlit                 1.31.1
# sympy                     1.12
# tenacity                  8.2.3
# terminado                 0.18.0
# threadpoolctl             3.3.0
# tinycss2                  1.2.1
# tokenizers                0.15.2
# toml                      0.10.2
# tomli                     2.0.1
# toolz                     0.12.1
# torch                     2.2.1
# tornado                   6.4
# tqdm                      4.66.2
# traitlets                 5.14.1
# transformers              4.38.2
# types-python-dateutil     2.8.19.20240106
# typing_extensions         4.10.0
# tzdata                    2024.1
# tzlocal                   5.2
# uri-template              1.3.0
# urllib3                   2.2.1
# validators                0.22.0
# watchdog                  4.0.0
# wcwidth                   0.2.13
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.7.0
# widgetsnbextension        4.0.10
# zipp                      3.17.0
#
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from song_vibe.constants import *
import os
os.chdir(ROOT_DIR)

using_streamlit = False
if using_streamlit:
    from song_vibe.ui.utils import load_data, load_model, load_index
else:
    from song_vibe.utils import load_data, load_model, load_index

# %%
df = load_data()

# %%
df
# Out:
#                                                    text  \
# 0     The song Deep Sea Creature by Mastodon has a d...
# 1     The song "I Didn't Mean To" by Casual has a me...
# 2     The song Soul Deep by The Box Tops has a soulf...
# 3     Amor De Cabaret - Sonora Santanera has a roman...
# 4     Something Girls by Adam Ant has an upbeat, ene...
# ...                                                 ...
# 1995  The song How I Miss You Tonight by Adolph Hofn...
# 1996  The song Night Life by Charlie McCoy has a mel...
# 1997  The song Shadows of the Thought by Suicide has...
# 1998  Wild Side by Mötley Crüe has a gritty, edgy, a...
# 1999  Aurora (Rory's Cassette Jam Remix) by Alex Gop...
#
#                                                category
# 0                          Deep Sea Creature - Mastodon
# 1                           I Didn't Mean To"" - Casual
# 2                              Soul Deep - The Box Tops
# 3                    Amor De Cabaret - Sonora Santanera
# 4                            Something Girls - Adam Ant
# ...                                                 ...
# 1995             How I Miss You Tonight - Adolph Hofner
# 1996                         Night Life - Charlie McCoy
# 1997                   Shadows of the thought - Suicide
# 1998              Wild Side - M\xc3\xb6tley Cr\xc3\xbce
# 1999  Aurora (Rory's Cassette Jam Remix)"" - Alex Go...
#
# [2000 rows x 2 columns]

# %%
encoder = load_model()
